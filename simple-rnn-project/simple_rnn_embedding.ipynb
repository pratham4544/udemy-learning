# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
# sentences

sent = [
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good'
]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
# define the vocablaury size

voc_size = 10000

# %%
# one hot representation

one_hot_repr = [one_hot(words,voc_size)for words in sent]

# %%
one_hot_repr
# Out:
# [[506, 9219, 1212, 7027],
#  [506, 9219, 1212, 2407],
#  [506, 8733, 1212, 1101],
#  [6061, 6324, 6742, 332, 1065],
#  [6061, 6324, 6742, 332, 6839],
#  [6198, 506, 2754, 1212, 5129],
#  [2183, 4, 8394, 332]]

# %%
# word embedding representation

from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0  506 9219 1212 7027]
#  [   0    0    0    0  506 9219 1212 2407]
#  [   0    0    0    0  506 8733 1212 1101]
#  [   0    0    0 6061 6324 6742  332 1065]
#  [   0    0    0 6061 6324 6742  332 6839]
#  [   0    0    0 6198  506 2754 1212 5129]
#  [   0    0    0    0 2183    4 8394  332]]

# %%
# feature representation

dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 127ms/step
# array([[[-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02191038,  0.02559651,  0.04880047,  0.01677458,
#           0.02321618,  0.02875084,  0.01986391, -0.02414184,
#          -0.03854728,  0.01285866],
#         [-0.00760939, -0.01452874, -0.01229854, -0.04989907,
#          -0.00751247, -0.02931684,  0.03420443, -0.04876707,
#           0.01477177, -0.02870615],
#         [-0.04161661, -0.01320002, -0.01528066, -0.02925014,
#          -0.02000303, -0.01630015,  0.024597  , -0.00465854,
#          -0.01135362,  0.03506945],
#         [ 0.011801  , -0.00698531,  0.0095646 , -0.01087475,
#          -0.04887096,  0.036743  ,  0.03612996, -0.00307293,
#           0.02883958, -0.01091672]],
#
#        [[-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02191038,  0.02559651,  0.04880047,  0.01677458,
#           0.02321618,  0.02875084,  0.01986391, -0.02414184,
#          -0.03854728,  0.01285866],
#         [-0.00760939, -0.01452874, -0.01229854, -0.04989907,
#          -0.00751247, -0.02931684,  0.03420443, -0.04876707,
#           0.01477177, -0.02870615],
#         [-0.04161661, -0.01320002, -0.01528066, -0.02925014,
#          -0.02000303, -0.01630015,  0.024597  , -0.00465854,
#          -0.01135362,  0.03506945],
#         [ 0.00196968,  0.01301262,  0.03907063, -0.02934828,
#           0.00424981, -0.02820929, -0.01162881,  0.0100732 ,
#          -0.00255079,  0.02299447]],
#
#        [[-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02191038,  0.02559651,  0.04880047,  0.01677458,
#           0.02321618,  0.02875084,  0.01986391, -0.02414184,
#          -0.03854728,  0.01285866],
#         [ 0.02568445,  0.04596046, -0.04130962,  0.00292342,
#          -0.01706948, -0.03947457,  0.04358789,  0.02801751,
#          -0.00885724, -0.03823292],
#         [-0.04161661, -0.01320002, -0.01528066, -0.02925014,
#          -0.02000303, -0.01630015,  0.024597  , -0.00465854,
#          -0.01135362,  0.03506945],
#         [ 0.03387994, -0.0186704 ,  0.04437851, -0.02723989,
#          -0.00529431, -0.00281294, -0.02857652,  0.04701022,
#           0.0254619 ,  0.02382408]],
#
#        [[-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.04065412,  0.02629304, -0.00090011, -0.02882917,
#           0.04898517,  0.03522874, -0.04333637,  0.0496075 ,
#          -0.04928824,  0.00879793],
#         [ 0.030311  , -0.00272274, -0.00447343,  0.01524447,
#           0.01533267, -0.01606231, -0.00267594,  0.01479724,
#          -0.03100932, -0.02785237],
#         [ 0.0353446 ,  0.00062349,  0.04900766,  0.04844247,
#           0.01677844,  0.04361837,  0.02971185, -0.04421855,
#           0.00574584,  0.0448742 ],
#         [ 0.01498062,  0.01888936, -0.01402198, -0.02989103,
#           0.00936573,  0.02414337, -0.03091074,  0.0042154 ,
#          -0.03903187, -0.03129923],
#         [-0.01664988,  0.04689046,  0.01508491, -0.02990706,
#           0.00651773,  0.03260613, -0.0141837 ,  0.04147056,
#           0.03731506, -0.02981774]],
#
#        [[-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.04065412,  0.02629304, -0.00090011, -0.02882917,
#           0.04898517,  0.03522874, -0.04333637,  0.0496075 ,
#          -0.04928824,  0.00879793],
#         [ 0.030311  , -0.00272274, -0.00447343,  0.01524447,
#           0.01533267, -0.01606231, -0.00267594,  0.01479724,
#          -0.03100932, -0.02785237],
#         [ 0.0353446 ,  0.00062349,  0.04900766,  0.04844247,
#           0.01677844,  0.04361837,  0.02971185, -0.04421855,
#           0.00574584,  0.0448742 ],
#         [ 0.01498062,  0.01888936, -0.01402198, -0.02989103,
#           0.00936573,  0.02414337, -0.03091074,  0.0042154 ,
#          -0.03903187, -0.03129923],
#         [ 0.03860557, -0.04453702,  0.02083937, -0.01701716,
#          -0.04442511,  0.0442014 ,  0.01583153,  0.03857942,
#           0.0349069 ,  0.01538685]],
#
#        [[-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [ 0.03952331,  0.00674769, -0.04473191,  0.02579438,
#           0.03132614, -0.03293286,  0.03667224,  0.03805571,
#           0.00970357, -0.04686395],
#         [-0.02191038,  0.02559651,  0.04880047,  0.01677458,
#           0.02321618,  0.02875084,  0.01986391, -0.02414184,
#          -0.03854728,  0.01285866],
#         [ 0.00201679, -0.0041322 ,  0.01603245,  0.00303891,
#           0.00176049,  0.04525026,  0.01063974,  0.03804323,
#           0.01240147,  0.01627399],
#         [-0.04161661, -0.01320002, -0.01528066, -0.02925014,
#          -0.02000303, -0.01630015,  0.024597  , -0.00465854,
#          -0.01135362,  0.03506945],
#         [ 0.01098283, -0.03665962,  0.01703176,  0.02132782,
#           0.01489288,  0.03666139,  0.0074861 ,  0.00898527,
#          -0.0342149 ,  0.00820113]],
#
#        [[-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.04375872, -0.04325961,  0.03794105,  0.03897687,
#           0.02657292,  0.00544522,  0.00996773,  0.04241954,
#           0.04031462,  0.02405323],
#         [ 0.02071687, -0.03575963, -0.02117567, -0.01263162,
#          -0.00707818,  0.00392795,  0.00210818,  0.00929035,
#           0.04842175,  0.01068108],
#         [ 0.01198124,  0.0329995 ,  0.00294977, -0.00632383,
#          -0.02991149,  0.00200176, -0.03265029, -0.04237781,
#           0.03201501,  0.00798167],
#         [ 0.01498062,  0.01888936, -0.01402198, -0.02989103,
#           0.00936573,  0.02414337, -0.03091074,  0.0042154 ,
#          -0.03903187, -0.03129923]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0,  506, 9219, 1212, 7027], dtype=int32)

# %%
model.predict(embedded_docs[[0]])
# Out:
# 1/1 [==============================] - 0s 26ms/step
# array([[[-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02375025, -0.03451303, -0.02223467, -0.02194401,
#           0.02753553, -0.0016981 , -0.03043584, -0.02680192,
#           0.00180999,  0.04172398],
#         [-0.02191038,  0.02559651,  0.04880047,  0.01677458,
#           0.02321618,  0.02875084,  0.01986391, -0.02414184,
#          -0.03854728,  0.01285866],
#         [-0.00760939, -0.01452874, -0.01229854, -0.04989907,
#          -0.00751247, -0.02931684,  0.03420443, -0.04876707,
#           0.01477177, -0.02870615],
#         [-0.04161661, -0.01320002, -0.01528066, -0.02925014,
#          -0.02000303, -0.01630015,  0.024597  , -0.00465854,
#          -0.01135362,  0.03506945],
#         [ 0.011801  , -0.00698531,  0.0095646 , -0.01087475,
#          -0.04887096,  0.036743  ,  0.03612996, -0.00307293,
#           0.02883958, -0.01091672]]], dtype=float32)
